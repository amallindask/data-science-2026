# %% [markdown]
# <a href="https://colab.research.google.com/github/amallindask/data-science-2026/blob/main/Pertemuan1_Amallinda_250401020003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IDENTITAS MAHASISWA**
#
# ---
#
# Nama : Amallinda Sekar Kinasih
#
# ---
#
# NIM : 250401020003
#
# ---
#
# Kelas : IF403

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================
#SEL 1 : Output sederhana

print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science

# %%
#SEL 2: Variable dan tipe data dasar
nama      = "Mahasiswa Informatika"     #String
angkatan  = 2024                        #Integer
ipk       = 3.75                        #Float
aktif     = True                        #Boolean

print(f"Nama      :{nama}")
print(f"Angkatan  :{angkatan}")
print(f"IPK       :{ipk}")
print(f"Aktif     :{aktif}")
# Out:
# Nama      :Mahasiswa Informatika
# Angkatan  :2024
# IPK       :3.75
# Aktif     :True

# %%
#SEL 3: List dan perulangan
tools = ["Python","Google Colab","Jupyter Notebook", "GitHub" ]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f"  {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. GitHub

# %%
#SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Amallinda Sekar Kinasih", "Informatika", "2024")
print(hasil)
# Out:
# Hai! Saya Amallinda Sekar Kinasih dari Informatika, angkatan 2024.

# %% [markdown]
# **Kesimpulan**
#
# ---
#
# Menurut saya, pada pertemuan 1 ini memperkenalkan dasar-dasar pemrograman Python seperti variabel, tipe data, list, perulangan, fungsi. Pertama, dapat memunculkan teks sederhana. Kedua, belajar membuat variabel lalu dipanggil untuk ditampilkan. Ketiga membuat list dengan menampilkan tools dengan nomor menurun ke bawah. Keempat, belajar membuat fungsi sederhana yang menampilkan kalimat perkenalan.
#
# ---
# Temuan untuk Environment Google Colab berjalan normal tanpa error. Kemudian struktur dasar fungsi dapat dipahami dengan baik, termasuk docstring dan return value.
#
# ---
#
# Pertanyaan selanjutnya yaitu bagaimana beralih dari dasar Python ke tools data science yang lebih spesifik seperti Pandas dan Matplotlib.
